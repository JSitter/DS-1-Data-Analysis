# %%
% cd ~/MakeSchool/DS1/DS-1-Data-Analysis/datasets/netneutrality
% pwd
# Out:
# /Users/justin/MakeSchool/DS1/DS-1-Data-Analysis/datasets/netneutrality
# '/Users/justin/MakeSchool/DS1/DS-1-Data-Analysis/datasets/netneutrality'

# %%
import pandas as pd

reps = pd.read_csv('~/MakeSchool/DS1/DS-1-Data-Analysis/datasets/netneutrality/us_house_of_reps.csv')
reps
# Out:
#                                                        District  \
# Alabama 1                           Byrne, BradleyBradley Byrne
# Alabama 2                               Roby, MarthaMartha Roby
# Alabama 3                               Rogers, MikeMike Rogers
# Alabama 4                       Aderholt, RobertRobert Aderholt
# Alabama 5                                   Brooks, MoMo Brooks
# Alabama 6                               Palmer, GaryGary Palmer
# Alabama 7                             Sewell, TerriTerri Sewell
# Alaska At Large                             Young, DonDon Young
# Arizona 1                         O'Halleran, TomTom O'Halleran
# Arizona 2                         McSally, MarthaMartha McSally
# Arizona 3                           Grijalva, RaúlRaúl Grijalva
# Arizona 4                                 Gosar, PaulPaul Gosar
# Arizona 5                                 Biggs, AndyAndy Biggs
# Arizona 6                     Schweikert, DavidDavid Schweikert
# ...
